# %%
# Check the files in Data
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import time
from torch.utils.data import Dataset, DataLoader
import torch
import torchtext
# from transformers import BertTokenizer # assuming you want to use BERT tokenizer
import torch.nn as nn

# %%
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/stockmarket-sentiment-dataset/stock_data.csv
# /kaggle/input/nlp-getting-started/sample_submission.csv
# /kaggle/input/nlp-getting-started/train.csv
# /kaggle/input/nlp-getting-started/test.csv

# %%
# Import Data

data_folder = '/kaggle/input/stockmarket-sentiment-dataset/'

test = pd.read_csv(data_folder + 'stock_data.csv')
train = pd.read_csv(data_folder + 'stock_data.csv')
train
# Out:
#                                                    Text  Sentiment
# 0     Kickers on my watchlist XIDE TIT SOQ PNK CPW B...          1
# 1     user: AAP MOVIE. 55% return for the FEA/GEED i...          1
# 2     user I'd be afraid to short AMZN - they are lo...          1
# 3                                     MNTA Over 12.00            1
# 4                                      OI  Over 21.37            1
# ...                                                 ...        ...
# 5786  Industry body CII said #discoms are likely to ...         -1
# 5787  #Gold prices slip below Rs 46,000 as #investor...         -1
# 5788  Workers at Bajaj Auto have agreed to a 10% wag...          1
# 5789  #Sharemarket LIVE: Sensex off day’s high, up 6...          1
# 5790  #Sensex, #Nifty climb off day's highs, still u...          1
#
# [5791 rows x 2 columns]

# %%
# to clean data
def normalise_text (text):
    text = text.str.lower() # lowercase
    text = text.str.replace(r"\#","") # replaces hashtags
    text = text.str.replace(r"http\S+","URL")  # remove URL addresses
    text = text.str.replace(r"@","")
    text = text.str.replace(r"[^A-Za-z0-9()!?\'\`\"]", " ")
    text = text.str.replace("\s{2,}", " ")
    return text

# %%
# drop 'id' , 'keyword' and 'location' columns.
# train.drop(columns=['id','keyword','location'], inplace=True)
# train["text"]=normalise_text(train["text"])

# %%
train = train.rename(columns = {'Text' : 'text','Sentiment':'target'})

# %%
train.loc[train['target'] == -1,'target'] = 0

train.head()
# Out:
#                                                 text  target
# 0  Kickers on my watchlist XIDE TIT SOQ PNK CPW B...       1
# 1  user: AAP MOVIE. 55% return for the FEA/GEED i...       1
# 2  user I'd be afraid to short AMZN - they are lo...       1
# 3                                  MNTA Over 12.00         1
# 4                                   OI  Over 21.37         1

# %%
# split data into train and validation 
train_df, valid_df = train_test_split(train)

# %%
# tokenizer = torchtext.data.get_tokenizer("basic_english")

class CustomDataset(Dataset):
    def __init__(self, dataframe, tokenizer):
        self.data = []
        for i, row in dataframe.iterrows():
            text, target = row['text'], row['target']
            self.data.append((text, int(target)))
            self.tokenizer = tokenizer

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        text, target = self.data[idx]
        inputs = self.tokenizer(text, padding='max_length', truncation=True, max_length=76, return_tensors='pt')
        inputs_ids = inputs['input_ids'].squeeze(0)
        attention_masks = inputs['attention_mask'].squeeze(0)
        return inputs_ids, attention_masks, target

# %% [markdown]
# Determine the maximum length of the sentence

# %%
from transformers import RobertaTokenizer, RobertaForSequenceClassification

tokenizer = RobertaTokenizer.from_pretrained('roberta-base') # or any other tokenizer
sentences = train["text"]
sentences_tokenized = [tokenizer.tokenize(sentence) for sentence in sentences ]
# tokenizer.convert_tokens_to_ids(tokenizer.tokenize(sentence0))
# print('Max sentence length: ', max([len(sen) for sen in input_ids]))
# Out:
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/481 [00:00<?, ?B/s]

# %%
print('Max sentence length: ', max([len(sen) for sen in sentences_tokenized]))
# Out:
# Max sentence length:  66

# %%
train_dataset = CustomDataset(train_df, tokenizer)
val_dataset = CustomDataset(valid_df, tokenizer)

batch_size = 32
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True)
# inputs_ids, attention_masks, label = next(iter(train_dataloader))
# print(label.shape)

# %%
from transformers import AdamW, RobertaConfig

# %%
# Load BertForSequenceClassification, the pretrained BERT model with a single 
# linear classification layer on top. 
model = RobertaForSequenceClassification.from_pretrained(
    'roberta-base', # Use the 12-layer BERT model, with an uncased vocab.
    num_labels = 2, # The number of output labels--2 for binary classification.
                    # You can increase this for multi-class tasks.   
    output_attentions = False, # Whether the model returns attentions weights.
    output_hidden_states = False, # Whether the model returns all hidden-states.
)

# model that we keep for validation
best_model = RobertaForSequenceClassification.from_pretrained(
    'roberta-base', # Use the 12-layer BERT model, with an uncased vocab.
    num_labels = 2, # The number of output labels--2 for binary classification.
                    # You can increase this for multi-class tasks.   
    output_attentions = False, # Whether the model returns attentions weights.
    output_hidden_states = False, # Whether the model returns all hidden-states.
)
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'roberta.pooler.dense.weight', 'lm_head.bias', 'roberta.pooler.dense.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.bias', 'classifier.out_proj.weight', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'roberta.pooler.dense.weight', 'lm_head.bias', 'roberta.pooler.dense.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.bias', 'classifier.out_proj.weight', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Define the device to run the model on (CPU or GPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Tell pytorch to run this model on the GPU.
model = model.to(device)

# %%
# Get all of the model's parameters as a list of tuples.
params = list(model.named_parameters())

print('The BERT model has {:} different named parameters.\n'.format(len(params)))

print('==== Embedding Layer ====\n')

for p in params[0:5]:
    print("{:<55} {:>12}".format(p[0], str(tuple(p[1].size()))))

print('\n==== First Transformer ====\n')

for p in params[5:21]:
    print("{:<55} {:>12}".format(p[0], str(tuple(p[1].size()))))

print('\n==== Output Layer ====\n')

for p in params[-4:]:
    print("{:<55} {:>12}".format(p[0], str(tuple(p[1].size()))))

# %% [markdown]
# Optimizer

# %%
# Note: AdamW is a class from the huggingface library (as opposed to pytorch) 
# I believe the 'W' stands for 'Weight Decay fix"
optimizer = AdamW (model.parameters(),
                  lr =1e-6, # args.learning_rate - default is 5e-5, our notebook had 2e-5
                  eps = 1e-8, # args.adam_epsilon  - default is 1e-8.
                  weight_decay=0.05
                )
# Out:
# /opt/conda/lib/python3.7/site-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,

# %%
from transformers import get_linear_schedule_with_warmup

# Number of training epochs (authors recommend between 2 and 4)
epochs = 50
# Total number of training steps is number of batches * number of epochs.
total_steps = len(train_dataloader) * epochs
# Create the learning rate scheduler.
scheduler = get_linear_schedule_with_warmup(optimizer, 
                                            num_warmup_steps = 0, # Default value in run_glue.py
                                            num_training_steps = total_steps)

# %% [markdown]
# Create function to calculate accuracy

# %%
import numpy as np
from torch.nn import functional as F

def compute_acc(preds, labels):
    correct = 0
    preds_ = preds.data.max(1)[1]
    correct = preds_.eq(labels.data).cpu().sum()
    acc = float(correct) / float(len(labels.data)) * 100.0
    return acc

# %%
import time
import datetime

def format_time(elapsed):
    '''
    Takes a time in seconds and returns a string hh:mm:ss
    '''
    # Round to the nearest second.
    elapsed_rounded = int(round((elapsed)))
    
    # Format as hh:mm:ss
    return str(datetime.timedelta(seconds=elapsed_rounded))

# %%
# for param in model.base_model.parameters():
#     param.requires_grad = False

# %%
def plot_loss_accuracy(train_losses, val_losses, train_accuracies, val_accuracies):
    fig, axs = plt.subplots(1, 2, figsize=(10, 5))
    axs[0].plot(train_losses, label='Train Loss')
    axs[0].plot(val_losses, label='Validation Loss')
    axs[0].set_title("Losses over Epochs")
    axs[0].set_xlabel("Epoch")
    axs[0].set_ylabel("Loss")
    axs[0].legend()
    
    axs[1].plot(train_accuracies, label='Train Accuracy')
    axs[1].plot(val_accuracies, label='Validation Accuracy')
    axs[1].set_title("Accuracies over Epochs")
    axs[1].set_xlabel("Epoch")
    axs[1].set_ylabel("Accuracy")
    axs[1].legend()
    
    plt.tight_layout()
#     plt.savefig(path)

# %%
patience = 4 
num_no_improvement = 0 

# Store the average loss after each epoch so we can plot them.
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []
show_every = 20

# Keep track of the best validation loss
best_val_loss = float('inf')


# For each epoch...
for epoch_i in range(0, epochs):
    
    store_train_loss = []
    store_train_acc = []
    store_val_loss = []
    store_val_acc = []
    
     # ========================================
    #               Training
    # ========================================
    
    # Perform one full pass over the training set.
    print("")
    print('======== Epoch {:} / {:} ========'.format(epoch_i + 1, epochs))
    print('Training...')
    # Measure how long the training epoch takes.
    t0 = time.time()
    # Reset the total loss for this epoch.
    total_loss = 0
    
    model.train()
    
    
    # For each batch of training data...
    for step, batch in enumerate(train_dataloader):
        
        
        # Add batch to GPU
        batch = tuple(t.to(device) for t in batch)
        inputs_ids, attention_masks, labels = batch
        model.zero_grad()
        
        # Perform a forward pass (evaluate the model on this training batch).
        # This will return the loss (rather than the model output) because we
        # have provided the `labels`.
        # The documentation for this `model` function is here: 
        # https://huggingface.co/transformers/v2.2.0/model_doc/bert.html#transformers.BertForSequenceClassification
        outputs = model(inputs_ids, 
                    attention_mask=attention_masks)
        
#         print(outputs[0])
#         print(labels.shape)
#         print(outputs[0].shape)
        loss = F.cross_entropy(outputs[0], labels)
#         print(outputs.shape)
        
        train_acc = compute_acc(outputs[0], labels)

        # Print the statistics
        store_train_loss.append(loss.item())
        store_train_acc.append(train_acc)
        
        # Perform a backward pass to calculate the gradients.
        loss.backward()
        
        # This is to help prevent the "exploding gradients" problem.
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        
        optimizer.step()

        # Update the learning rate.
        scheduler.step()
        
        # Progress update every 40 batches.
        if step % show_every == 0 and not step == 0:
            # Calculate elapsed time in minutes.
            elapsed = format_time(time.time() - t0)
            # Report progress.
            print('  Batch {} / {}.  Elapsed: {:}.'.format(step, len(train_dataloader), elapsed))
            print('Training loss: %.3f  Training acc: %.3f'%(np.mean(store_train_loss[-show_every:]), np.mean(store_train_acc[-show_every:])) ) 
    
        
    # compute epoch loss and accuracy 
    train_losses.append(np.mean(store_train_loss))
    train_accuracies.append(np.mean(store_train_acc))
    
    print("  Training epoch took: {:}".format(format_time(time.time() - t0)))
    
    
    # ========================================
    #               Validation
    # ========================================
    # After the completion of each training epoch, measure our performance on
    # our validation set.
    
    print("")
    print("Running Validation...")

    t0 = time.time()

    # Put the model in evaluation mode--the dropout layers behave differently
    # during evaluation.
    model.eval()
    
    # Evaluate data for one epoch
    for batch in val_dataloader:
        
        # Add batch to GPU
        batch = tuple(t.to(device) for t in batch)
        
        # Unpack the inputs from our dataloader
        val_inputs_ids, val_attention_masks, val_labels = batch
        
        # Telling the model not to compute or store gradients, saving memory and
        # speeding up validation
        with torch.no_grad():  
            val_outputs = model(val_inputs_ids,  
                            attention_mask=val_attention_masks)
            
        # Get the "logits" output by the model. The "logits" are the output
        # values prior to applying an activation function like the softmax.
        val_logits = val_outputs[0]
        
        val_loss = F.cross_entropy(val_logits, val_labels)
        
        # Calculate the accuracy for this batch of test sentences.
        val_acc = compute_acc(val_logits, val_labels)
        
        store_val_loss.append(val_loss.item())
        store_val_acc.append(val_acc)
        
    
    # compute epoch loss and accuracy 
    mean_val_loss = np.mean(store_val_loss)
    val_losses.append(mean_val_loss)
    val_accuracies.append(np.mean(store_val_acc))
        
    # Report the final accuracy for this validation run.
    # Print loss and acc at the end of the epoch
    print("Epoch {}: Train Loss: {:.4f}, Validation Loss: {:.4f}, Train Accuracy: {:.2f}%, Validation Accuracy: {:.2f}%".format
    (epoch_i, train_losses[-1], val_losses[-1], train_accuracies[-1], val_accuracies[-1]))
    


    #Check if validation loss has improved
    if np.mean(mean_val_loss < best_val_loss):
        best_val_loss = mean_val_loss
        # Get the current state of the model
        model_state_dict = model.state_dict()
        best_model.load_state_dict(model_state_dict)
        num_no_improvement = 0 
    else:
        num_no_improvement+=1 
    if num_no_improvement == patience: 
        break

        
print("")
print("Training complete!")
# Out:
# ======== Epoch 1 / 50 ========
# Training...
#   Batch 20 / 136.  Elapsed: 0:00:10.
# Training loss: 0.714  Training acc: 39.688
#   Batch 40 / 136.  Elapsed: 0:00:18.
# Training loss: 0.701  Training acc: 44.375
#   Batch 60 / 136.  Elapsed: 0:00:25.
# Training loss: 0.683  Training acc: 56.719
#   Batch 80 / 136.  Elapsed: 0:00:33.
# Training loss: 0.680  Training acc: 60.938
#   Batch 100 / 136.  Elapsed: 0:00:41.
# Training loss: 0.661  Training acc: 63.438
#   Batch 120 / 136.  Elapsed: 0:00:49.
# Training loss: 0.662  Training acc: 62.031
#   Training epoch took: 0:00:55
#
# Running Validation...
# Epoch 0: Train Loss: 0.6792, Validation Loss: 0.6483, Train Accuracy: 55.65%, Validation Accuracy: 63.59%
#
# ======== Epoch 2 / 50 ========
# Training...
#   Batch 20 / 136.  Elapsed: 0:00:09.
# Training loss: 0.655  Training acc: 63.438
#   Batch 40 / 136.  Elapsed: 0:00:17.
# Training loss: 0.656  Training acc: 61.562
#   Batch 60 / 136.  Elapsed: 0:00:25.
# Training loss: 0.639  Training acc: 63.906
#   Batch 80 / 136.  Elapsed: 0:00:34.
# Training loss: 0.635  Training acc: 63.906
#   Batch 100 / 136.  Elapsed: 0:00:42.
# Training loss: 0.630  Training acc: 64.531
#   Batch 120 / 136.  Elapsed: 0:00:51.
# Training loss: 0.616  Training acc: 66.406
#   Training epoch took: 0:00:57
#
# Running Validation...
# Epoch 1: Train Loss: 0.6382, Validation Loss: 0.6244, Train Accuracy: 63.88%, Validation Accuracy: 63.18%
#
# ======== Epoch 3 / 50 ========
# Training...
#   Batch 20 / 136.  Elapsed: 0:00:09.
# Training loss: 0.636  Training acc: 61.875
#   Batch 40 / 136.  Elapsed: 0:00:17.
# Training loss: 0.595  Training acc: 66.719
#   Batch 60 / 136.  Elapsed: 0:00:25.
# Training loss: 0.595  Training acc: 65.156
#   Batch 80 / 136.  Elapsed: 0:00:34.
# Training loss: 0.581  Training acc: 67.656
#   Batch 100 / 136.  Elapsed: 0:00:42.
# Training loss: 0.562  Training acc: 70.000
#   Batch 120 / 136.  Elapsed: 0:00:50.
# Training loss: 0.568  Training acc: 69.688
#   Training epoch took: 0:00:57
#
# Running Validation...
# Epoch 2: Train Loss: 0.5824, Validation Loss: 0.5216, Train Accuracy: 67.70%, Validation Accuracy: 76.36%
#
# ======== Epoch 4 / 50 ========
# Training...
#   Batch 20 / 136.  Elapsed: 0:00:09.
# Training loss: 0.529  Training acc: 75.312
#   Batch 40 / 136.  Elapsed: 0:00:17.
# Training loss: 0.482  Training acc: 81.719
#   Batch 60 / 136.  Elapsed: 0:00:26.
# Training loss: 0.494  Training acc: 76.875
#   Batch 80 / 136.  Elapsed: 0:00:34.
# Training loss: 0.513  Training acc: 74.375
#   Batch 100 / 136.  Elapsed: 0:00:42.
# Training loss: 0.467  Training acc: 80.000
#   Batch 120 / 136.  Elapsed: 0:00:51.
# Training loss: 0.492  Training acc: 77.031
#   Training epoch took: 0:00:57
#
# Running Validation...
# Epoch 3: Train Loss: 0.4986, Validation Loss: 0.4771, Train Accuracy: 77.18%, Validation Accuracy: 78.19%
#
# ======== Epoch 5 / 50 ========
# Training...
#   Batch 20 / 136.  Elapsed: 0:00:09.
# Training loss: 0.494  Training acc: 77.031
#   Batch 40 / 136.  Elapsed: 0:00:17.
# Training loss: 0.477  Training acc: 78.438
#   Batch 60 / 136.  Elapsed: 0:00:25.
# Training loss: 0.449  Training acc: 80.469
#   Batch 80 / 136.  Elapsed: 0:00:34.
# Training loss: 0.451  Training acc: 80.156
#   Batch 100 / 136.  Elapsed: 0:00:42.
# Training loss: 0.489  Training acc: 77.656
#   Batch 120 / 136.  Elapsed: 0:00:51.
# Training loss: 0.447  Training acc: 80.469
#   Training epoch took: 0:00:57
#
# Running Validation...
# Epoch 4: Train Loss: 0.4678, Validation Loss: 0.4693, Train Accuracy: 78.80%, Validation Accuracy: 79.55%
#
# ======== Epoch 6 / 50 ========
# Training...
#   Batch 20 / 136.  Elapsed: 0:00:09.
# Training loss: 0.491  Training acc: 78.281
#   Batch 40 / 136.  Elapsed: 0:00:17.
# Training loss: 0.460  Training acc: 78.438
#   Batch 60 / 136.  Elapsed: 0:00:25.
# Training loss: 0.471  Training acc: 79.219
#   Batch 80 / 136.  Elapsed: 0:00:34.
# Training loss: 0.439  Training acc: 81.250
#   Batch 100 / 136.  Elapsed: 0:00:42.
# Training loss: 0.443  Training acc: 79.844
#   Batch 120 / 136.  Elapsed: 0:00:51.
# Training loss: 0.460  Training acc: 79.688
#   Training epoch took: 0:00:57
#
# Running Validation...
# Epoch 5: Train Loss: 0.4534, Validation Loss: 0.4559, Train Accuracy: 79.77%, Validation Accuracy: 80.23%
#
# ======== Epoch 7 / 50 ========
# Training...
#   Batch 20 / 136.  Elapsed: 0:00:09.
# Training loss: 0.433  Training acc: 81.406
#   Batch 40 / 136.  Elapsed: 0:00:17.
# Training loss: 0.436  Training acc: 80.938
#   Batch 60 / 136.  Elapsed: 0:00:25.
# Training loss: 0.433  Training acc: 80.938
#   Batch 80 / 136.  Elapsed: 0:00:34.
# Training loss: 0.469  Training acc: 79.062
#   Batch 100 / 136.  Elapsed: 0:00:42.
# Training loss: 0.437  Training acc: 80.000
#   Batch 120 / 136.  Elapsed: 0:00:50.
# Training loss: 0.413  Training acc: 83.125
#   Training epoch took: 0:00:57
#
# Running Validation...
# Epoch 6: Train Loss: 0.4353, Validation Loss: 0.4471, Train Accuracy: 80.94%, Validation Accuracy: 81.11%
#
# ======== Epoch 8 / 50 ========
# Training...
#   Batch 20 / 136.  Elapsed: 0:00:09.
# Training loss: 0.381  Training acc: 85.156
#   Batch 40 / 136.  Elapsed: 0:00:17.
# Training loss: 0.409  Training acc: 81.719
#   Batch 60 / 136.  Elapsed: 0:00:25.
# Training loss: 0.429  Training acc: 81.719
#   Batch 80 / 136.  Elapsed: 0:00:34.
# Training loss: 0.387  Training acc: 84.375
#   Batch 100 / 136.  Elapsed: 0:00:42.
# Training loss: 0.431  Training acc: 81.562
#   Batch 120 / 136.  Elapsed: 0:00:51.
# Training loss: 0.385  Training acc: 84.062
#   Training epoch took: 0:00:57
#
# Running Validation...
# Epoch 7: Train Loss: 0.4035, Validation Loss: 0.4426, Train Accuracy: 83.07%, Validation Accuracy: 80.98%
#
# ======== Epoch 9 / 50 ========
# Training...
#   Batch 20 / 136.  Elapsed: 0:00:09.
# Training loss: 0.380  Training acc: 84.219
#   Batch 40 / 136.  Elapsed: 0:00:17.
# Training loss: 0.380  Training acc: 84.219
#   Batch 60 / 136.  Elapsed: 0:00:25.
# Training loss: 0.421  Training acc: 81.562
#   Batch 80 / 136.  Elapsed: 0:00:34.
# Training loss: 0.400  Training acc: 83.281
#   Batch 100 / 136.  Elapsed: 0:00:42.
# Training loss: 0.393  Training acc: 83.906
#   Batch 120 / 136.  Elapsed: 0:00:50.
# Training loss: 0.400  Training acc: 82.188
#   Training epoch took: 0:00:57
#
# Running Validation...
# Epoch 8: Train Loss: 0.4044, Validation Loss: 0.4364, Train Accuracy: 82.86%, Validation Accuracy: 81.18%
#
# ======== Epoch 10 / 50 ========
# Training...
#   Batch 20 / 136.  Elapsed: 0:00:09.
# Training loss: 0.385  Training acc: 83.906
#   Batch 40 / 136.  Elapsed: 0:00:17.
# Training loss: 0.385  Training acc: 83.750
#   Batch 60 / 136.  Elapsed: 0:00:25.
# Training loss: 0.409  Training acc: 82.656
#   Batch 80 / 136.  Elapsed: 0:00:34.
# Training loss: 0.363  Training acc: 84.844
#   Batch 100 / 136.  Elapsed: 0:00:42.
# Training loss: 0.426  Training acc: 80.156
#   Batch 120 / 136.  Elapsed: 0:00:51.
# Training loss: 0.356  Training acc: 85.781
#   Training epoch took: 0:00:57
#
# Running Validation...
# Epoch 9: Train Loss: 0.3884, Validation Loss: 0.4402, Train Accuracy: 83.42%, Validation Accuracy: 81.11%
#
# ======== Epoch 11 / 50 ========
# Training...
#   Batch 20 / 136.  Elapsed: 0:00:09.
# Training loss: 0.372  Training acc: 85.312
#   Batch 40 / 136.  Elapsed: 0:00:17.
# Training loss: 0.376  Training acc: 84.062
#   Batch 60 / 136.  Elapsed: 0:00:25.
# Training loss: 0.372  Training acc: 84.531
#   Batch 80 / 136.  Elapsed: 0:00:34.
# Training loss: 0.372  Training acc: 82.812
#   Batch 100 / 136.  Elapsed: 0:00:42.
# Training loss: 0.400  Training acc: 82.812
#   Batch 120 / 136.  Elapsed: 0:00:51.
# Training loss: 0.383  Training acc: 83.594
#   Training epoch took: 0:00:57
#
# Running Validation...
# Epoch 10: Train Loss: 0.3765, Validation Loss: 0.4537, Train Accuracy: 83.95%, Validation Accuracy: 79.82%
#
# ======== Epoch 12 / 50 ========
# Training...
#   Batch 20 / 136.  Elapsed: 0:00:09.
# Training loss: 0.379  Training acc: 84.531
#   Batch 40 / 136.  Elapsed: 0:00:17.
# Training loss: 0.381  Training acc: 83.906
#   Batch 60 / 136.  Elapsed: 0:00:25.
# Training loss: 0.340  Training acc: 85.781
#   Batch 80 / 136.  Elapsed: 0:00:34.
# Training loss: 0.381  Training acc: 84.062
#   Batch 100 / 136.  Elapsed: 0:00:42.
# Training loss: 0.363  Training acc: 85.000
#   Batch 120 / 136.  Elapsed: 0:00:51.
# Training loss: 0.370  Training acc: 84.688
#   Training epoch took: 0:00:57
#
# Running Validation...
# Epoch 11: Train Loss: 0.3648, Validation Loss: 0.4443, Train Accuracy: 84.84%, Validation Accuracy: 80.03%
#
# ======== Epoch 13 / 50 ========
# Training...
#   Batch 20 / 136.  Elapsed: 0:00:09.
# Training loss: 0.347  Training acc: 85.938
#   Batch 40 / 136.  Elapsed: 0:00:17.
# Training loss: 0.345  Training acc: 86.719
#   Batch 60 / 136.  Elapsed: 0:00:25.
# Training loss: 0.370  Training acc: 84.688
#   Batch 80 / 136.  Elapsed: 0:00:34.
# Training loss: 0.369  Training acc: 85.312
#   Batch 100 / 136.  Elapsed: 0:00:42.
# Training loss: 0.348  Training acc: 86.406
#   Batch 120 / 136.  Elapsed: 0:00:50.
# Training loss: 0.339  Training acc: 86.094
#   Training epoch took: 0:00:57
#
# Running Validation...
# Epoch 12: Train Loss: 0.3543, Validation Loss: 0.4326, Train Accuracy: 85.70%, Validation Accuracy: 81.39%
#
# ======== Epoch 14 / 50 ========
# Training...
#   Batch 20 / 136.  Elapsed: 0:00:09.
# Training loss: 0.346  Training acc: 86.094
#   Batch 40 / 136.  Elapsed: 0:00:17.
# Training loss: 0.314  Training acc: 87.969
#   Batch 60 / 136.  Elapsed: 0:00:25.
# Training loss: 0.350  Training acc: 85.781
#   Batch 80 / 136.  Elapsed: 0:00:34.
# Training loss: 0.389  Training acc: 84.375
#   Batch 100 / 136.  Elapsed: 0:00:42.
# Training loss: 0.361  Training acc: 84.688
#   Batch 120 / 136.  Elapsed: 0:00:51.
# Training loss: 0.344  Training acc: 85.938
#   Training epoch took: 0:00:57
#
# Running Validation...
# Epoch 13: Train Loss: 0.3465, Validation Loss: 0.4464, Train Accuracy: 85.99%, Validation Accuracy: 81.11%
#
# ======== Epoch 15 / 50 ========
# Training...
#   Batch 20 / 136.  Elapsed: 0:00:09.
# Training loss: 0.327  Training acc: 85.938
#   Batch 40 / 136.  Elapsed: 0:00:17.
# Training loss: 0.366  Training acc: 85.625
#   Batch 60 / 136.  Elapsed: 0:00:25.
# Training loss: 0.301  Training acc: 87.812
#   Batch 80 / 136.  Elapsed: 0:00:34.
# Training loss: 0.318  Training acc: 87.031
#   Batch 100 / 136.  Elapsed: 0:00:42.
# Training loss: 0.340  Training acc: 86.562
#   Batch 120 / 136.  Elapsed: 0:00:50.
# Training loss: 0.317  Training acc: 87.031
#   Training epoch took: 0:00:57
#
# Running Validation...
# Epoch 14: Train Loss: 0.3320, Validation Loss: 0.4431, Train Accuracy: 86.56%, Validation Accuracy: 82.00%
#
# ======== Epoch 16 / 50 ========
# Training...
#   Batch 20 / 136.  Elapsed: 0:00:09.
# Training loss: 0.360  Training acc: 84.844
#   Batch 40 / 136.  Elapsed: 0:00:17.
# Training loss: 0.293  Training acc: 88.750
#   Batch 60 / 136.  Elapsed: 0:00:25.
# Training loss: 0.306  Training acc: 88.125
#   Batch 80 / 136.  Elapsed: 0:00:34.
# Training loss: 0.317  Training acc: 86.250
#   Batch 100 / 136.  Elapsed: 0:00:42.
# Training loss: 0.326  Training acc: 86.875
#   Batch 120 / 136.  Elapsed: 0:00:51.
# Training loss: 0.359  Training acc: 85.469
#   Training epoch took: 0:00:57
#
# Running Validation...
# Epoch 15: Train Loss: 0.3262, Validation Loss: 0.4459, Train Accuracy: 86.70%, Validation Accuracy: 81.45%
#
# ======== Epoch 17 / 50 ========
# Training...
#   Batch 20 / 136.  Elapsed: 0:00:09.
# Training loss: 0.316  Training acc: 86.719
#   Batch 40 / 136.  Elapsed: 0:00:17.
# Training loss: 0.330  Training acc: 87.656
#   Batch 60 / 136.  Elapsed: 0:00:26.
# Training loss: 0.322  Training acc: 87.344
#   Batch 80 / 136.  Elapsed: 0:00:34.
# Training loss: 0.328  Training acc: 87.031
#   Batch 100 / 136.  Elapsed: 0:00:42.
# Training loss: 0.313  Training acc: 87.344
#   Batch 120 / 136.  Elapsed: 0:00:51.
# Training loss: 0.340  Training acc: 86.406
#   Training epoch took: 0:00:57
#
# Running Validation...
# Epoch 16: Train Loss: 0.3226, Validation Loss: 0.4437, Train Accuracy: 87.20%, Validation Accuracy: 81.66%
#
# Training complete!

# %%
plot_loss_accuracy(train_losses, val_losses, train_accuracies, val_accuracies)

# %%
test = pd.read_csv('/kaggle/input/testingdata/tweets.csv')
test.drop(['Unnamed: 0','Date','User'], axis = 1,inplace = True)

# %%
test
# Out:
#                                                  Tweet
# 0    Unity meta token Malaysia event https://t.co/s...
# 1    【Amazon co jp 限定】 アイ・オー・データ IODATA モニター 23 8イン...
# 2    $TRV Real-time stock analyses ratings and targ...
# 3    I have nearly 1 million LOTR follower on Faceb...
# 4    @SupriyaShrinate Akele Amit Malviya ne pura co...
# ..                                                 ...
# 495  ＼写真集 TOP3／ 04/09 00:00取得\n2位🥈\n\n櫻坂46 大園玲1st写真...
# 496  $SNX Real-time stock analyses ratings and targ...
# 497  @nytimes You mean he’s running the same exact ...
# 498  karena stock akun udah sold semua, cici mau of...
# 499  Amazon ビジネス書の売れ筋ランキング 1位は\nコンサル一年目が学ぶこと\n大石哲之\...
#
# [500 rows x 1 columns]

# %%
test["Tweet"]=normalise_text(test["Tweet"])
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   after removing the cwd from sys.path.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   """
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   import sys
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: The default value of regex will change from True to False in a future version.

# %%
test = test.rename(columns = {'Tweet' : 'text'})

# %%
# test.drop(columns=['keyword','location'], inplace=True)



test['target'] = 0

test_dataset = CustomDataset(test, tokenizer)
batch_size = 8
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# Load the state dictionary into the model

# Set the model to evaluation mode
best_model.to(device)
best_model.eval()


store_test_acc = []

store_predictions = torch.zeros(len(test_dataset), dtype=torch.int)

# For each batch of training data...
for step, batch in enumerate(test_dataloader):
    
    
    # Add batch to GPU
    batch = tuple(t.to(device) for t in batch)
    inputs_ids, attention_masks, labels = batch
    with torch.no_grad():
        outputs = best_model(inputs_ids, 
                    token_type_ids=None, 
                    attention_mask=attention_masks)
        predictions = torch.max(outputs[0], dim=1)[1]
        store_predictions[step*len(predictions): (step+1)*len(predictions)] = predictions
        # store_test_acc.append(compute_acc(outputs[0], labels))


store_predictions = store_predictions.detach().cpu().numpy()

test['target'] = store_predictions

# test.drop(columns=['text'], inplace=True)

test.to_csv('submission.csv', index=False)


print("Finished testing")
# Out:
# Finished testing

# %%
test
# Out:
#                                                   text  target
# 0                  unity meta token malaysia event URL       1
# 1     amazon co jp iodata 23 8 fhd 1080p ads 5ms (h...       1
# 2     trv real time stock analyses ratings and targ...       1
# 3    i have nearly 1 million lotr follower on faceb...       0
# 4    supriyashrinate akele amit malviya ne pura con...       1
# ..                                                 ...     ...
# 495            top3 04 09 00 00 2 46 1st URL amazon ad       1
# 496   snx real time stock analyses ratings and targ...       0
# 497  nytimes you mean he s running the same exact p...       0
# 498  karena stock akun udah sold semua cici mau off...       0
# 499                     amazon 1 URL 2023 04 09 01 URL       0
#
# [500 rows x 2 columns]

# %%
substring = 'google'

# substring = 'jan'
mask = test.applymap(lambda x: substring in x.lower() if isinstance(x,str) else False).to_numpy()
indices = np.argwhere(mask)

# %%
count_1 = int(0)
count_0 = int(0)
for i in range(len(indices)):
    var = test.iloc[indices[i][0]]['target']
    if var == 1:
        count_1 += 1 
    else :
        count_0 += 1

print(count_1)
print(count_0)
avg = count_1/(count_1 + count_0)
print(avg*10)

# if count_1>=count_0:
#     print('buy')
# else:
#     print("don't buy")
# Out:
# 72
# 14
# 8.372093023255815

# %%
PATH = '/kaggle/working/best_model'
torch.save(model.state_dict(), PATH)
